# %%
import requests
from main import Finance

# %%
API_KEY = '896123476cd9c8becbc6e08ba9eb5108'

# %%
cf = Finance()

# %%
companies_response = requests.get(f'https://fmpcloud.io/api/v3/stock-screener?sector=technology&marketCapMoreThan=100000000000&limit=100&apikey={API_KEY}')
companies = companies_response.json()

# %%
companies
# Out:
# [{'symbol': 'SSUN.F',
#   'companyName': 'Samsung Electronics Co., Ltd.',
#   'marketCap': 9618741788672,
#   'sector': 'Technology',
#   'industry': 'Consumer Electronics',
#   'beta': 0.9265,
#   'price': 1232.0,
#   'lastAnnualDividend': 23.2386,
#   'volume': 246,
#   'exchange': 'Frankfurt',
#   'exchangeShortName': 'EURONEXT',
#   'country': 'US',
#   'isEtf': False,
#   'isActivelyTrading': True},
#  {'symbol': 'AAPL',
#   'companyName': 'Apple Inc.',
#   'marketCap': 2813301358592,
#   'sector': 'Technology',
#   'industry': 'Consumer Electronics',
#   'beta': 1.2027,
#   'price': 172.39,
#   'lastAnnualDividend': 0.88,
#   'volume': 101007314,
#   'exchange': 'Nasdaq Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'country': 'US',
#   'isEtf': False,
#   'isActivelyTrading': True},
#  {'symbol': 'MSFT',
#   'companyName': 'Microsoft Corporation',
#   'marketCap': 2293592489984,
#   'sector': 'Technology',
#   'industry': 'Software—Infrastructure',
#   'beta': 0.8621,
# ...

# %%
len(companies)
# Out:
# 27

# %%
company_names = []
for i in companies:
    company_names.append(i['companyName'])

company_names
# Out:
# ['Samsung Electronics Co., Ltd.',
#  'Apple Inc.',
#  'Microsoft Corporation',
#  'Taiwan Semiconductor Manufacturing Company Limited',
#  'NVIDIA Corporation',
#  'ASML Holding N.V.',
#  'Cisco Systems, Inc.',
#  'Broadcom Inc.',
#  'Adobe Inc.',
#  'Cisco Systems, Inc.',
#  'ASML Holding N.V.',
#  'Accenture plc',
#  'Oracle Corporation',
#  'salesforce.com, inc.',
#  'QUALCOMM Incorporated',
#  'Intel Corporation',
#  'Intel Corporation',
#  'Texas Instruments Incorporated',
#  'Intuit Inc.',
#  'Advanced Micro Devices, Inc.',
#  'SAP SE',
#  'Shopify Inc.',
#  'Sony Group Corporation',
#  'International Business Machines Corporation',
#  'Applied Materials, Inc.',
#  'ServiceNow, Inc.',
#  'Shopify Inc.']
